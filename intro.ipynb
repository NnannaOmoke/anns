# %%
import pandas as pan
import numpy as np
import matplotlib.pyplot as plotter
import seaborn as sns

# %%
matrix_data = pan.read_csv("fake_reg.csv")

# %%
sns.scatterplot(x = matrix_data["feature1"], y = matrix_data["feature2"], hue = matrix_data["price"])
# Out:
# <Axes: xlabel='feature1', ylabel='feature2'>

# %%
sns.pairplot(matrix_data)
